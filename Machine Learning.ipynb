# %% [markdown]
# <a href="https://colab.research.google.com/github/CoutinhoAlves/Machine-Learning/blob/main/Machine%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Mikael");
# Out:
# Mikael
